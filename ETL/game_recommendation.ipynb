# %%
import pandas as pd

# %%
games = pd.read_parquet('../Dataset\games_sistem.parquet')

# %%
games.head()
# Out:
#        id                    title            developer release_date  \
# 0  761140      Lost Summoner Kitty            Kotoshiro   2018-01-04
# 1  643980                Ironbound     Secret Level SRL   2018-01-04
# 2  670290  Real Pool 3D - Poolians         Poolians.com   2017-07-24
# 3  767400                  弹炸人2222                 彼岸领域   2017-12-07
# 4  772540    Battle Royale Trainer  Trickjump Games Ltd   2018-01-04
#
#                                               genres  \
# 0      [Action, Casual, Indie, Simulation, Strategy]
# 1               [Free to Play, Indie, RPG, Strategy]
# 2  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                        [Action, Adventure, Casual]
# 4                    [Action, Adventure, Simulation]
#
#                                                 tags  price
# 0      [Strategy, Action, Indie, Casual, Simulation]   4.99
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...   0.00
# 2  [Free to Play, Simulation, Sports, Casual, Ind...   0.00
# 3                        [Action, Adventure, Casual]   0.99
# 4  [Action, Adventure, Simulation, FPS, Shooter, ...   3.99

# %%
games = games.explode(column='genres')

# Ahora voy a restablecer el índice del Df resultante y descartare el índice anterior
games = games.reset_index(drop=True)
games
# Out:
#            id                title                 developer release_date  \
# 0      761140  Lost Summoner Kitty                 Kotoshiro   2018-01-04
# 1      761140  Lost Summoner Kitty                 Kotoshiro   2018-01-04
# 2      761140  Lost Summoner Kitty                 Kotoshiro   2018-01-04
# 3      761140  Lost Summoner Kitty                 Kotoshiro   2018-01-04
# 4      761140  Lost Summoner Kitty                 Kotoshiro   2018-01-04
# ...       ...                  ...                       ...          ...
# 55607  610660        Russian Roads  Laush Dmitriy Sergeevich   2018-01-04
# 55608  610660        Russian Roads  Laush Dmitriy Sergeevich   2018-01-04
# 55609  610660        Russian Roads  Laush Dmitriy Sergeevich   2018-01-04
# 55610  658870  EXIT 2 - Directions             xropi,stev3ns   2017-09-02
# 55611  658870  EXIT 2 - Directions             xropi,stev3ns   2017-09-02
#
#            genres                                               tags  price
# 0          Action      [Strategy, Action, Indie, Casual, Simulation]   4.99
# 1          Casual      [Strategy, Action, Indie, Casual, Simulation]   4.99
# 2           Indie      [Strategy, Action, Indie, Casual, Simulation]   4.99
# 3      Simulation      [Strategy, Action, Indie, Casual, Simulation]   4.99
# 4        Strategy      [Strategy, Action, Indie, Casual, Simulation]   4.99
# ...           ...                                                ...    ...
# 55607       Indie                        [Indie, Simulation, Racing]   1.99
# 55608      Racing                        [Indie, Simulation, Racing]   1.99
# 55609  Simulation                        [Indie, Simulation, Racing]   1.99
# 55610      Casual  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...   4.99
# 55611       Indie  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...   4.99
#
# [55612 rows x 7 columns]

# %%
# Columnas innecesarias
games.drop(['price', 'release_date'], axis=1, inplace=True)

# %%
games
# Out:
#            id                title                 developer      genres  \
# 0      761140  Lost Summoner Kitty                 Kotoshiro      Action
# 1      761140  Lost Summoner Kitty                 Kotoshiro      Casual
# 2      761140  Lost Summoner Kitty                 Kotoshiro       Indie
# 3      761140  Lost Summoner Kitty                 Kotoshiro  Simulation
# 4      761140  Lost Summoner Kitty                 Kotoshiro    Strategy
# ...       ...                  ...                       ...         ...
# 55607  610660        Russian Roads  Laush Dmitriy Sergeevich       Indie
# 55608  610660        Russian Roads  Laush Dmitriy Sergeevich      Racing
# 55609  610660        Russian Roads  Laush Dmitriy Sergeevich  Simulation
# 55610  658870  EXIT 2 - Directions             xropi,stev3ns      Casual
# 55611  658870  EXIT 2 - Directions             xropi,stev3ns       Indie
#
#                                                     tags
# 0          [Strategy, Action, Indie, Casual, Simulation]
# 1          [Strategy, Action, Indie, Casual, Simulation]
# 2          [Strategy, Action, Indie, Casual, Simulation]
# 3          [Strategy, Action, Indie, Casual, Simulation]
# 4          [Strategy, Action, Indie, Casual, Simulation]
# ...                                                  ...
# 55607                        [Indie, Simulation, Racing]
# 55608                        [Indie, Simulation, Racing]
# 55609                        [Indie, Simulation, Racing]
# 55610  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 55611  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
#
# [55612 rows x 5 columns]

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55612 entries, 0 to 55611
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         55612 non-null  object
#  1   title      55612 non-null  object
#  2   developer  55612 non-null  object
#  3   genres     55612 non-null  object
#  4   tags       55612 non-null  object
# dtypes: object(5)
# memory usage: 2.1+ MB

# %%
games.columns
# Out:
# Index(['id', 'title', 'developer', 'genres', 'tags'], dtype='object')

# %%
# Columnas innecesarias
games.drop(['tags', 'developer'], axis=1, inplace=True)

# %%
games.head()
# Out:
#        id                title      genres
# 0  761140  Lost Summoner Kitty      Action
# 1  761140  Lost Summoner Kitty      Casual
# 2  761140  Lost Summoner Kitty       Indie
# 3  761140  Lost Summoner Kitty  Simulation
# 4  761140  Lost Summoner Kitty    Strategy

# %%
games.shape
# Out:
# (55612, 3)

# %%
# Eliminación de duplicados
games.drop_duplicates(subset='title', keep='first', inplace=True)

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.head(15)
# Out:
#         id                                              title        genres
# 0   761140                                Lost Summoner Kitty        Action
# 5   643980                                          Ironbound  Free to Play
# 9   670290                            Real Pool 3D - Poolians        Casual
# 14  767400                                            弹炸人2222        Action
# 17  772540                              Battle Royale Trainer        Action
# 20  774277                         SNOW - All Access Pro Pass  Free to Play
# 24  774278                      SNOW - All Access Legend Pass  Free to Play
# 28  770380  Army of Tentacles: (Not) A Cthulhu Dating Sim:...        Action
# 33  768880                                        Beach Rules        Casual
# 35  765320                        Planetarium 2 - Zen Odyssey        Casual
# 38  773650                            The first thrust of God     Adventure
# 43  774271                                SNOW - Starter Pack  Free to Play
# 47  773690            The first thrust of God - All Aircrafts     Adventure
# 52  774279                               SNOW - Lifetime Pack  Free to Play
# 56  768060                           The Warrior Of Treasures        Action

# %%
# Guardamos el dataset en parquet con formato de compresión snappy para mayor velocidad de lectura.
games.to_parquet('../Dataset/game_recommendation.parquet', compression='snappy', index=False)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# @app.get('/Recomendacion Juego', tags=['Recomendacion'])
def recomendacion_juego(id_de_producto: int):
    
    '''Ingresa un ID de un juego y retorna una lista de juegos similares que te pueden interesar 
    usan un modelo de similitud del coseno'''

    games = pd.read_parquet('../Dataset/game_recommendation.parquet')

    atributos = games[games['id'] == id_de_producto]
    
    if atributos.empty:
        return 'No se encontró un juego con el ID proporcionado, prueba otro ID.'
    
    juegos = games[games['genres'] == atributos['genres'].iloc[0]]
    juegos= juegos[['title','genres']]
    juegos['caracteristicas'] = juegos[['genres']].apply(lambda row: '-'.join(row.values.astype(str)), axis=1) 
    juegos= juegos[['title','caracteristicas']].iloc[:1001,:]
    
    vector= TfidfVectorizer()
    matriz= vector.fit_transform(juegos['caracteristicas'])
    matriz_similaridad= cosine_similarity(matriz)
    
    indice_juego = juegos.index[juegos['title'] == atributos['title'].iloc[0]].tolist()[0]
    similares = list(enumerate(matriz_similaridad[indice_juego]))
    similaridades = sorted(similares, key=lambda x: x[1], reverse=True)[1:6]
    juegos_recomendados = [juegos.iloc[i[0]]['title'] for i in similaridades]
    
    return {'Juegos similares que te pueden interesar': juegos_recomendados}

recomendacion_juego("670290")
# Out:
# {'Juegos similares que te pueden interesar': ['Beach Rules',
#   'Planetarium 2 - Zen Odyssey',
#   'Vaporwave Simulator',
#   'Chronicles of Vinland',
#   'Zen of Sudoku']}

# %%
"""def game_recomend(id):
    df = pd.read_parquet('../Dataset/game_recommendation.parquet')
    if id not in df['id'].values:
        return "ID no encontrado"
    
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(df['genres'])
    cosine_sim = cosine_similarity(tfidf_matrix)
    
    idx = df[df['id'] == id].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:11]
    
    recommended_games = df['title'].iloc[[i[0] for i in sim_scores]].tolist()
    return {'recommended_games': recommended_games}

# Llamada a la función
game_recomend(761140)"""
# Out:
# 'ID no encontrado'

# %%
"""pruebas = pd.read_parquet('../Dataset/game_recommendation.parquet')
pruebas"""
# Out:
#            id                     title        genres
# 0      761140       Lost Summoner Kitty        Action
# 1      643980                 Ironbound  Free to Play
# 2      670290   Real Pool 3D - Poolians        Casual
# 3      767400                   弹炸人2222        Action
# 4      772540     Battle Royale Trainer        Action
# ...       ...                       ...           ...
# 22508  745400              Kebab it Up!        Action
# 22509  773640            Colony On Mars        Casual
# 22510  733530  LOGistICAL: South Africa        Casual
# 22511  610660             Russian Roads         Indie
# 22512  658870       EXIT 2 - Directions        Casual
#
# [22513 rows x 3 columns]

# %%
"""def recomendacion_juego(id_de_producto: int):
    
    '''Ingresa un ID de un juego y retorna una lista de juegos similares que te pueden interesar 
    usan un modelo de similitud del coseno'''
    pruebas = pd.read_parquet('../Dataset/game_recommendation.parquet')

    atributos = pruebas[pruebas['id'] == id_de_producto]
    
    if atributos.empty:
        return 'No se encontró un juego con el ID proporcionado, prueba otro ID.'
    
    juegos = pruebas[pruebas['genres'] == atributos['genres'].iloc[0]]
    juegos= juegos[['title','genres']]
    juegos['caracteristicas'] = juegos[['genres']].apply(lambda row: '-'.join(row.values.astype(str)), axis=1) 
    juegos= juegos[['title','caracteristicas']].iloc[:1001,:]
    
    vector= TfidfVectorizer()
    matriz= vector.fit_transform(juegos['caracteristicas'])
    matriz_similaridad= cosine_similarity(matriz)
    
    indice_juego = juegos.index[juegos['title'] == atributos['title'].iloc[0]].tolist()[0]
    similares = list(enumerate(matriz_similaridad[indice_juego]))
    similaridades = sorted(similares, key=lambda x: x[1], reverse=True)[1:6]
    juegos_recomendados = [juegos.iloc[i[0]]['title'] for i in similaridades]
    
    return {'Juegos similares que te pueden interesar': juegos_recomendados}

recomendacion_juego(658870)"""
# Out:
# 'No se encontró un juego con el ID proporcionado, prueba otro ID.'
